# %%
# %pylab inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import object_detect as od
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
im_size = (15,12)

# %% [markdown]
# To view run the object detection using image urls, you need to pass in the image url as the parameter to the function, which returns a filepath, of the object detected file.

# %%
import pandas as pd

test_data = pd.read_csv('data/test/product_images.csv')
test_data.head(n=20)
# Out:
#     Unnamed: 0           ImageID Subset  \
# 0          138  004a9388fb6fd9fc   test
# 1          179  0056ffa38a8489b6   test
# 2          189  005c99e22cfe182f   test
# 3          431  00d8bf5411fdfe51   test
# 4          504  00ff185256c0dc67   test
# 5          563  012161ba1f688d43   test
# 6          573  012570c9ec60f9c4   test
# 7          598  0133239017fa03d7   test
# 8          615  0138be05352840a0   test
# 9          678  01586b20eb69c4ba   test
# 10         714  01681d52ad599ab4   test
# 11         717  016943a933c0b836   test
# 12         789  0192deb7b7fade4c   test
# 13         822  01a4b22028ed8133   test
# 14         838  01ac026097ecc699   test
# 15         883  01bfc6a5c53e5086   test
# 16        1277  027b5c62f38fc44e   test
# 17        1375  02a9c2709448d6ab   test
# 18        1430  02c37cca4253f49f   test
# 19        1448  02ca56a928857d93   test
#
#                                           OriginalURL  \
# ...

# %%
path,res = od.objdetfromurl('https://c2.staticflickr.com/4/3459/4553694405_730a772276_o.jpg')

# %%
img=mpimg.imread(path)
plt.figure(figsize=im_size)
plt.imshow(img)

# %%
res
# Out:
# {'Calculator': {'bbox': array([ 0.18735999,  0.10654454,  0.91190666,  0.90112662], dtype=float32),
#   'score': 0.61588919},
#  'Mobile phone': {'bbox': array([ 0.05546483,  0.08749717,  0.90944707,  0.90565848], dtype=float32),
#   'score': 0.97587276}}

# %% [markdown]
# For object detection using image name, you can select any of the image ids from the above test dataframe and add '.jpg' , then pass it as a parameter to the function.

# %%
img_path, img_res = od.objdetfromname('012570c9ec60f9c4.jpg')

# %%
image=mpimg.imread(img_path)
plt.figure(figsize=im_size)
plt.imshow(image)

# %%
img_res
# Out:
# {'Refrigerator': {'bbox': array([ 0.13965043,  0.48694217,  1.        ,  1.        ], dtype=float32),
#   'score': 0.75972962}}
